# %%
#set is unordered colection 
s = {1,2,20,'hi',4.5}
print(s)
# Out:
# {1, 2, 'hi', 4.5, 20}

# %%
#set allows only unique elements              ob1.union(obj2) | intersection & difference - isdisjoint symmetric_difference issubset issuperset 
s = {1,2,2,2,332,934,93,9}
print(s)
# Out:
# {1, 2, 934, 9, 332, 93}

# %%
s = set(map(int,input().split()))
print(min(s))
print(max(s))
print(sum(s))
print(len(s))
# Out:
#  1 23 23 2 1 3 5 6
# 1
# 23
# 40
# 6
